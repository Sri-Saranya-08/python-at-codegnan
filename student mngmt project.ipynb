# %%
def greet():
    print("Welcome to student management system")
greet()
# Out:
# Welcome to student management system

# %%
def welcome():
    print("Welcome to student management system")
    print("Have a nice day")
welcome()
# Out:
# Welcome to student management system
# Have a nice day

# %%
def welcome():
    print("Welcome saranya")
welcome()
# Out:
# Welcome saranya

# %%
student = {"id":1001,"name":"saranya","course":"python"}
print(student)
# Out:
# {'id': 1001, 'name': 'saranya', 'course': 'python'}

# %%
student={}
def add_student():
    student["id"] = 101
    student["name"] = "Saranya"
    student["course"] = "Python"
add_student()
print(student)
# Out:
# {'id': 101, 'name': 'Saranya', 'course': 'Python'}

# %%
student={}
def add_student():
    student["id"] = 101
    student["name"] = "Saranya"
    student["course"] = "Python"
    student["age"] = 15
    student["marks"] = 95
add_student()
print(student)
# Out:
# {'id': 101, 'name': 'Saranya', 'course': 'Python', 'age': 15, 'marks': 95}

# %%
student = {}
def add_student():
    student["id"] = input("Enter the student id")
    student["name"] = input("Enter the student name")
    student["course"] = input("Enter the student course")
    student["age"] = int(input("Enter the student age"))
    student["marks"] = int(input("Enter the student marks"))
add_student()
print(student)
# Out:
# Enter the student id 201
# Enter the student name saranya
# Enter the student course python
# Enter the student age 20
# Enter the student marks 250
# {'id': '201', 'name': 'saranya', 'course': 'python', 'age': 20, 'marks': 250}

# %%
students = []

def add_student():
    student = {}
    student["id"] = input("Enter the student id: ")
    student["name"] = input("Enter the student name: ")
    student["course"] = input("Enter the student course: ")
    student["age"] = int(input("Enter the student age: "))
    student["marks"] = int(input("Enter the student marks: "))

    students.append(student)
    print("Student Added Successfully!")

add_student()

print(students)
# Out:
# Enter the student id:  101
# Enter the student name:  saranya
# Enter the student course:  python
# Enter the student age:  20
# Enter the student marks:  98
# Student Added Successfully!
# [{'id': '101', 'name': 'saranya', 'course': 'python', 'age': 20, 'marks': 98}]

# %%
# Student Management System

students = []

# Add Student
def add_student():
    student = {}

    student["id"] = input("Enter Student ID: ")
    student["name"] = input("Enter Student Name: ")
    student["course"] = input("Enter Student Course: ")
    student["age"] = int(input("Enter Student Age: "))
    student["marks"] = int(input("Enter Student Marks: "))

    students.append(student)
    print("Student Added Successfully!")

# View Students
def view_students():
    if len(students) == 0:
        print("No Students Found")
    else:
        for student in students:
            print(student)

# Search Student
def search_student():
    sid = input("Enter Student ID to Search: ")

    for student in students:
        if student["id"] == sid:
            print("Student Found")
            print(student)
            return

    print("Student Not Found")

# Update Student
def update_student():
    sid = input("Enter Student ID to Update: ")

    for student in students:
        if student["id"] == sid:
            student["name"] = input("Enter New Name: ")
            student["course"] = input("Enter New Course: ")
            student["age"] = int(input("Enter New Age: "))
            student["marks"] = int(input("Enter New Marks: "))

            print("Student Updated Successfully!")
            return

    print("Student Not Found")

# Delete Student
def delete_student():
    sid = input("Enter Student ID to Delete: ")

    for student in students:
        if student["id"] == sid:
            students.remove(student)
            print("Student Deleted Successfully!")
            return

    print("Student Not Found")


# Function Calls

add_student()
add_student()

print("\n----- All Students -----")
view_students()

print("\n----- Search Student -----")
search_student()

print("\n----- Update Student -----")
update_student()

print("\n----- Students After Update -----")
view_students()

print("\n----- Delete Student -----")
delete_student()

print("\n----- Students After Delete -----")
view_students()
# Out:
# Enter Student ID:  201
# Enter Student Name:  saranya
# Enter Student Course:  python
# Enter Student Age:  21
# Enter Student Marks:  98
# Student Added Successfully!
# Enter Student ID:  202
# Enter Student Name:  sri
# Enter Student Course:  java
# Enter Student Age:  22
# Enter Student Marks:  99
# Student Added Successfully!
#
# ----- All Students -----
# {'id': '201', 'name': 'saranya', 'course': 'python', 'age': 21, 'marks': 98}
# {'id': '202', 'name': 'sri', 'course': 'java', 'age': 22, 'marks': 99}
#
# ----- Search Student -----

# %%
students = []

# Add Student 
def add_student():
    student = {}

    student["id"] = input("Enter Student ID: ")
    student["name"] = input("Enter Student Name: ")
    student["course"] = input("Enter Student Course: ")
    student["age"] = int(input("Enter Student Age: "))
    student["marks"] = int(input("Enter Student Marks: "))

    students.append(student)
    print("Student Added Successfully!")

# View Students
def view_students():
    if len(students) == 0:
        print("No Students Found")
    else:
        print("\n------ Student Details ------")
        for student in students:
            print(f"ID     : {student['id']}")
            print(f"Name   : {student['name']}")
            print(f"Course : {student['course']}")
            print(f"Age    : {student['age']}")
            print(f"Marks  : {student['marks']}")
            print("----------------------------")

# Search Student
def search_student():
    sid = input("Enter Student ID to Search: ")

    for student in students:
        if student["id"] == sid:
            print("\nStudent Found")
            print(f"ID     : {student['id']}")
            print(f"Name   : {student['name']}")
            print(f"Course : {student['course']}")
            print(f"Age    : {student['age']}")
            print(f"Marks  : {student['marks']}")
            return

    print("Student Not Found")

# Update Student 
def update_student():
    sid = input("Enter Student ID to Update: ")

    for student in students:
        if student["id"] == sid:
            student["name"] = input("Enter New Name: ")
            student["course"] = input("Enter New Course: ")
            student["age"] = int(input("Enter New Age: "))
            student["marks"] = int(input("Enter New Marks: "))

            print("Student Updated Successfully!")
            return

    print("Student Not Found")

# %%
students = []

# Add Student
def add_student():
    student = {}

    student["id"] = input("Enter Student ID : ")
    student["name"] = input("Enter Student Name : ")
    student["course"] = input("Enter Student Course : ")
    student["age"] = int(input("Enter Student Age : "))
    student["marks"] = int(input("Enter Student Marks : "))

    students.append(student)
    print("Student Added Successfully")


# View Students
def view_students():

    if len(students) == 0:
        print("No Students Found")

    else:
        for student in students:
            print("Student ID :", student["id"])
            print("Student Name :", student["name"])
            print("Student Course :", student["course"])
            print("Student Age :", student["age"])
            print("Student Marks :", student["marks"])
            print()


# Search Student
def search_student():

    sid = input("Enter Student ID : ")

    for student in students:

        if student["id"] == sid:
            print("Student Found")
            print("Student ID :", student["id"])
            print("Student Name :", student["name"])
            print("Student Course :", student["course"])
            print("Student Age :", student["age"])
            print("Student Marks :", student["marks"])
            return

    print("Student Not Found")


# Update Student
def update_student():

    sid = input("Enter Student ID : ")

    for student in students:

        if student["id"] == sid:

            student["name"] = input("Enter New Name : ")
            student["course"] = input("Enter New Course : ")
            student["age"] = int(input("Enter New Age : "))
            student["marks"] = int(input("Enter New Marks : "))

            print("Student Updated Successfully")
            return

    print("Student Not Found")


# Delete Student
def delete_student():

    sid = input("Enter Student ID : ")

    for student in students:

        if student["id"] == sid:
            students.remove(student)
            print("Student Deleted Successfully")
            return

    print("Student Not Found")


# Menu

while True:

    print("\n===== Student Management System =====")
    print("1. Add Student")
    print("2. View Students")
    print("3. Search Student")
    print("4. Update Student")
    print("5. Delete Student")
    print("6. Exit")

    choice = int(input("Enter Your Choice : "))

    if choice == 1:
        add_student()

    elif choice == 2:
        view_students()

    elif choice == 3:
        search_student()

    elif choice == 4:
        update_student()

    elif choice == 5:
        delete_student()

    elif choice == 6:
        print("Thank You")
        break

    else:
        print("Invalid Choice")
# Out:
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter Your Choice :  1
# Enter Student ID :  101
# Enter Student Name :  saranya
# Enter Student Course :  python
# Enter Student Age :  20
# Enter Student Marks :  99
# Student Added Successfully
#
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter Your Choice :  2
# Student ID : 101
# Student Name : saranya
# Student Course : python
# Student Age : 20
# Student Marks : 99
#
#
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter Your Choice :  202
# Invalid Choice
#
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter Your Choice :  3
# Enter Student ID :  101
# Student Found
# Student ID : 101
# Student Name : saranya
# Student Course : python
# Student Age : 20
# Student Marks : 99
#
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter Your Choice :  4
# Enter Student ID :  202
# Student Not Found
#
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter Your Choice :  5
# Enter Student ID :  108
# Student Not Found
#
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter Your Choice :  6
# Thank You
